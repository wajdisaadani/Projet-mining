# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import pandas as pd

s=Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=s)
driver.maximize_window()
driver.get('https://www.youtube.com/c/realmadrid/videos')

#driver.find_element(By.NAME, 'q').send_keys('')
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 102.0.5005
# [WDM] - Get LATEST chromedriver version for 102.0.5005 google-chrome
# [WDM] - Driver [/Users/clarkkent/.wdm/drivers/chromedriver/mac64/102.0.5005.61/chromedriver] found in cache

# %%
chaine_titre=driver.find_elements(By.XPATH,'//*[@id="video-title"]')
chaine_vue=driver.find_elements(By.XPATH,'//*[@id="metadata-line"]/span[1]')
chaine_date=driver.find_elements(By.XPATH,'//*[@id="metadata-line"]/span[2]')

Videos=[] 
i=0

# %%
for i in range(len(chaine_titre)):
    video_info={}
    
    video_info['titre']=chaine_titre[i].text
    video_info['vue']=chaine_vue[i].text
    video_info['date']=chaine_date[i].text
  
    
    Videos.append(video_info)

# %%
Videos
# Out:
# [{'titre': "Real Madrid's Champions League dressing room celebrations!",
#   'vue': '2 M de vues',
#   'date': 'il y a 8 heures'},
#  {'titre': 'READY for the CHAMPIONS LEAGUE FINAL | Liverpool-Real Madrid',
#   'vue': '620 k vues',
#   'date': 'il y a 1 jour'},
#  {'titre': 'Rueda de prensa | Ancelotti, Courtois y Marcelo | Final de Champions League',
#   'vue': '248 k vues',
#   'date': 'Diffusé il y a 1 jour'},
#  {'titre': '🇫🇷 Karim Benzema à la maison ! #shorts #realmadridshorts',
#   'vue': '130 k vues',
#   'date': 'il y a 2 jours'},
#  {'titre': 'Real Madrid are in PARIS | Champions League Diaries',
#   'vue': '837 k vues',
#   'date': 'il y a 2 jours'},
#  {'titre': 'Final TRAINING session before PARIS | Real Madrid',
#   'vue': '499 k vues',
#   'date': 'il y a 2 jours'},
#  {'titre': 'How many Real Madrid players have 4 European Cups? | Nacho & Carvajal QUIZ',
#   'vue': '232 k vues',
#   'date': 'il y a 3 jours'},
# ...

# %%
df_polytech=pd.DataFrame(Videos,columns=['titre','vue','date'] )

# %%
df_polytech
# Out:
#                                                 titre            vue  \
# 0   Real Madrid's Champions League dressing room c...    2 M de vues
# 1   READY for the CHAMPIONS LEAGUE FINAL | Liverpo...     620 k vues
# 2   Rueda de prensa | Ancelotti, Courtois y Marcel...     248 k vues
# 3   🇫🇷 Karim Benzema à la maison ! #shorts #realma...     130 k vues
# 4   Real Madrid are in PARIS | Champions League Di...     837 k vues
# 5   Final TRAINING session before PARIS | Real Madrid     499 k vues
# 6   How many Real Madrid players have 4 European C...     232 k vues
# 7   Unstoppable | #easymarkets #shortsrealmadrid #...      72 k vues
# 8   ALL of Real Madrid's CHAMPIONS LEAGUE FINAL GOALS     226 k vues
# 9   BEHIND THE SCENES on OPEN MEDIA DAY | Real Madrid     264 k vues
# 10  A Real Madrid dream come true: From Atlanta to...      87 k vues
# 11  👕 Real Madrid’s Champions League final shirt i...     197 k vues
# 12  How many Champions League teams can you name? ...     693 k vues
# ...

# %%
x=df_polytech.copy()
